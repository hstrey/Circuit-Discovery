# %%
import Pkg
Pkg.add("DifferentialEquations")
Pkg.add("Distributions")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  99.9 %0.0 %12.6 %>                             ]  25.3 %Fetching: [================>                        ]  37.9 %                   ]  50.5 % [==========================>              ]  63.1 %.5 %>       ]  80.2 %======================================>  ]  92.8 % Resolving package versions...
#  Installed ArgCheck ─────────────── v1.1.0
#  Installed IntervalSets ─────────── v0.4.0
#  Installed DiffEqPhysics ────────── v3.5.0
#  Installed Adapt ────────────────── v1.0.1
#  Installed ChainRulesCore ───────── v0.6.1
#  Installed NNlib ────────────────── v0.6.4
#  Installed BandedMatrices ───────── v0.14.3
#  Installed EllipsisNotation ─────── v0.4.0
#  Installed DiffRules ────────────── v1.0.1
#  Installed Parsers ──────────────── v0.3.11
#  Installed PyCall ───────────────── v1.91.3
#  Installed PlotUtils ────────────── v0.6.3
#  Installed NLSolversBase ────────── v7.6.1
#  Installed OrdinaryDiffEq ───────── v5.29.0
#  Installed OpenBLAS_jll ─────────── v0.3.7+5
#  Installed StatsFuns ────────────── v0.9.4
#  Installed MacroTools ───────────── v0.5.4
#  Installed Ratios ───────────────── v0.4.0
#  Installed CategoricalArrays ────── v0.7.7
#  Installed SparseDiffTools ──────── v1.3.3
#  Installed Zygote ───────────────── v0.4.7
#  Installed RecursiveArrayTools ──── v2.1.0
#  Installed Bijectors ────────────── v0.5.2
#  Installed BoundaryValueDiffEq ──── v2.4.0
#  Installed PDMats ───────────────── v0.9.11
#  Installed MKL_jll ──────────────── v2019.0.117+2
#  Installed Optim ────────────────── v0.20.1
#  Installed ForwardDiff ──────────── v0.10.9
#  Installed StatsBase ────────────── v0.32.1
#  Installed ArrayInterface ───────── v2.4.1
#  Installed DimensionalPlotRecipes ─ v1.1.0
#  Installed Requires ─────────────── v1.0.1
#  Installed OffsetArrays ─────────── v1.0.2
#  Installed VertexSafeGraphs ─────── v0.1.1
#  Installed AdvancedHMC ──────────── v0.2.20
#  Installed NLsolve ──────────────── v4.3.0
#  Installed DataStructures ───────── v0.17.9
#  Installed Sundials ─────────────── v3.8.2
#  Installed DiffEqCallbacks ──────── v2.12.0
#  Installed DiffEqNoiseProcess ───── v3.9.0
#  Installed DiffEqBase ───────────── v6.16.0
#  Installed FiniteDiff ───────────── v2.2.0
#  Installed IRTools ──────────────── v0.3.1
#  Installed Conda ────────────────── v1.4.1
#  Installed MuladdMacro ──────────── v0.2.2
#  Installed ZeroMQ_jll ───────────── v4.3.2+0
#  Installed DelayDiffEq ──────────── v5.21.0
#  Installed DistributionsAD ──────── v0.1.4
#  Installed StochasticDiffEq ─────── v6.19.1
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [79e6a3ab] ↑ Adapt v1.0.0 ⇒ v1.0.1
#   [0bf59076] ↑ AdvancedHMC v0.2.19 ⇒ v0.2.20
#   [dce04be8] ↑ ArgCheck v1.0.1 ⇒ v1.1.0
#   [4fba245c] ↑ ArrayInterface v2.3.1 ⇒ v2.4.1
#   [aae01518] ↑ BandedMatrices v0.14.2 ⇒ v0.14.3
#   [76274a88] ↑ Bijectors v0.5.1 ⇒ v0.5.2
#   [764a87c0] ↑ BoundaryValueDiffEq v2.3.1 ⇒ v2.4.0
#   [49dc2e85] - Calculus v0.5.1
#   [324d7699] ↑ CategoricalArrays v0.7.6 ⇒ v0.7.7
#   [d360d2e6] ↑ ChainRulesCore v0.4.0 ⇒ v0.6.1
#   [8f4d0f93] ↑ Conda v1.3.0 ⇒ v1.4.1
#   [864edb3b] ↑ DataStructures v0.17.7 ⇒ v0.17.9
#   [bcd4f6db] ↑ DelayDiffEq v5.20.0 ⇒ v5.21.0
#   [2b5f629d] ↑ DiffEqBase v6.12.2 ⇒ v6.16.0
#   [459566f4] ↑ DiffEqCallbacks v2.11.0 ⇒ v2.12.0
#   [01453d9d] - DiffEqDiffTools v1.7.0
#   [77a26b50] ↑ DiffEqNoiseProcess v3.8.0 ⇒ v3.9.0
#   [055956cb] ↑ DiffEqPhysics v3.4.0 ⇒ v3.5.0
#   [b552c78f] ↑ DiffRules v1.0.0 ⇒ v1.0.1
#   [c619ae07] ↑ DimensionalPlotRecipes v1.0.0 ⇒ v1.1.0
#   [ced4e74d] ↑ DistributionsAD v0.1.3 ⇒ v0.1.4
#   [da5c29d0] + EllipsisNotation v0.4.0
#   [6a86dc24] + FiniteDiff v2.2.0
#   [f6369f11] ↑ ForwardDiff v0.10.8 ⇒ v0.10.9
#   [7869d1d1] ↑ IRTools v0.3.0 ⇒ v0.3.1
#   [a98d9a8b] ↓ Interpolations v0.12.6 ⇒ v0.12.5
#   [8197267c] ↑ IntervalSets v0.3.2 ⇒ v0.4.0
#   [856f044c] ↑ MKL_jll v2019.0.117+0 ⇒ v2019.0.117+2
#   [1914dd2f] ↑ MacroTools v0.5.3 ⇒ v0.5.4
#   [46d2c3a1] ↑ MuladdMacro v0.2.1 ⇒ v0.2.2
#   [d41bc354] ↑ NLSolversBase v7.5.0 ⇒ v7.6.1
#   [2774e3e8] ↑ NLsolve v4.2.0 ⇒ v4.3.0
#   [872c559c] ↑ NNlib v0.6.2 ⇒ v0.6.4
#   [6fe1bfb0] ↑ OffsetArrays v0.11.4 ⇒ v1.0.2
#   [4536629a] ↑ OpenBLAS_jll v0.3.7+4 ⇒ v0.3.7+5
#   [429524aa] ↑ Optim v0.19.7 ⇒ v0.20.1
#   [1dea7af3] ↑ OrdinaryDiffEq v5.27.1 ⇒ v5.29.0
#   [90014a1f] ↑ PDMats v0.9.10 ⇒ v0.9.11
#   [69de0a69] ↑ Parsers v0.3.10 ⇒ v0.3.11
#   [995b91a9] ↑ PlotUtils v0.6.1 ⇒ v0.6.3
#   [438e738f] ↑ PyCall v1.91.2 ⇒ v1.91.3
#   [c84ed2f1] ↑ Ratios v0.3.1 ⇒ v0.4.0
#   [731186ca] ↑ RecursiveArrayTools v2.0.0 ⇒ v2.1.0
#   [ae029012] ↑ Requires v1.0.0 ⇒ v1.0.1
#   [47a9eef4] ↑ SparseDiffTools v1.2.0 ⇒ v1.3.3
#   [2913bbd2] ↑ StatsBase v0.32.0 ⇒ v0.32.1
#   [4c63d2b9] ↑ StatsFuns v0.9.3 ⇒ v0.9.4
#   [789caeaf] ↑ StochasticDiffEq v6.17.1 ⇒ v6.19.1
#   [c3572dad] ↑ Sundials v3.8.1 ⇒ v3.8.2
#   [19fa3120] ↑ VertexSafeGraphs v0.1.0 ⇒ v0.1.1
#   [8f1865be] ↑ ZeroMQ_jll v4.3.1+0 ⇒ v4.3.2+0
#   [e88e6eb3] ↑ Zygote v0.4.5 ⇒ v0.4.7
#   Building NNlib ───→ `~/.julia/packages/NNlib/3krvM/deps/build.log`
#   Building Conda ───→ `~/.julia/packages/Conda/3rPhK/deps/build.log`
#   Building PyCall ──→ `~/.julia/packages/PyCall/kAhnQ/deps/build.log`
#   Building Sundials → `~/.julia/packages/Sundials/GuMs0/deps/build.log`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]

# %%
# autoregulation
using DifferentialEquations
f(u,p,t) = 1.0/(1+(u/0.5))-1.0*u
u0 = 0.0
tspan = (0.0,3.0)
prob = ODEProblem(f,u0,tspan)
sol = solve(prob, Tsit5(), reltol=1e-8, abstol=1e-8)

using Plots
plot(sol,linewidth=5,title="Solution to the linear ODE with a thick line",
     xaxis="Time (t)",yaxis="u(t)",legend=false) # legend=false
# Out:
# ┌ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1273

# %%
versioninfo()
# Out:
# Julia Version 1.3.1
# Commit 2d5741174c (2019-12-30 21:36 UTC)
# Platform Info:
#   OS: macOS (x86_64-apple-darwin18.6.0)
#   CPU: Intel(R) Core(TM) i7-8700K CPU @ 3.70GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-6.0.1 (ORCJIT, skylake)
